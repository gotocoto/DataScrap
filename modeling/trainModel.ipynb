# %%
import sqlite3

conn = sqlite3.connect('news.db')
curr = conn.cursor()
data = curr.execute('SELECT REPLACE(REPLACE(c1.content,"<p>",""),"</p>","") as parent_comment,REPLACE(REPLACE(c2.content,"<p>","") ,"</p>","")as child_comment FROM comment as c1, comment as c2 WHERE c1.id = c2.parent_id;')
dataTable = data.fetchall()
conn.close()

# %%
import sqlite3
from bs4 import BeautifulSoup

# Connect to the SQLite database
conn = sqlite3.connect('news.db')
cursor = conn.cursor()

# Query the database for comments and replies
cursor.execute('SELECT REPLACE(REPLACE(c1.content,"<p>",""),"</p>","") as parent_comment,REPLACE(REPLACE(c2.content,"<p>","") ,"</p>","")as child_comment FROM comment as c1, comment as c2 WHERE c1.id = c2.parent_id;')
data = cursor.fetchall()

# Close the database connection
conn.close()

# Clean up text by removing HTML elements
def clean_text(text):
    soup = BeautifulSoup(text, 'html.parser')
    cleaned_text = soup.get_text(separator=' ', strip=True)
    return cleaned_text

# Example of cleaning comments and replies
cleaned_data = [(clean_text(comment), clean_text(reply)) for comment, reply in data]
# Out:
# /tmp/ipykernel_9743/4039238407.py:17: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, 'html.parser')

# %%
cleaned_data
# Out:
# [('They wanted it concealed because the chinese were paying them to let it happen',
#   'Or blackmailing Biden'),
#  ('Or blackmailing Biden', 'Free ice cream.'),
#  ('Or blackmailing Biden',
#   'I believe that Ukraine and China are blackmailing the Bidens and all the other corrupt politicians who have been on the take all these years.'),
#  ('They wanted it concealed because the chinese were paying them to let it happen',
#   'Joe Biden is bought, paid for, and owned by the Chairman Xi.'),
#  ('Joe Biden is bought, paid for, and owned by the Chairman Xi.',
#   "The world sees Joe Biden and Chairman Xi's boy ."),
#  ('Joe Biden is bought, paid for, and owned by the Chairman Xi.',
#   'Joe Biden America\'s "Manchurian Candidate" if there ever was ! !'),
#  ('They wanted it concealed because the chinese were paying them to let it happen',
#   'Or he’s afraid to challenge them.'),
#  ('They wanted it concealed because the chinese were paying them to let it happen',
#   "22,000+ Chinese illegals have crossed the southern border in the first 9 months of this year alone.  It's strange that Red China is getting such a free pass on everything in the USA since 10%joe was installed.  China has bought over 200,000 agricultural acres in the USA, and other properties, some near military bases."),
#  ("22,000+ Chinese illegals have crossed the southern border in the first 9 months of this year alone.  It's strange that Red China is getting such a free pass on everything in the USA since 10%joe was installed.  China has bought over 200,000 agricultural acres in the USA, and other properties, some near military bases.",
#   'And have countless spies in our universities and corporations and businesses.'),
#  ('How do you even start a conversation on this ?! Shame on you fox',
#   'Patriots for President Trump.biden was told to say “Donald Trump and the MAGA Republicans, represent an extremism that threatens our republic,” .  Dont be tricked by the lies of the democrats.  Their new plan is... {"they have to try to get as many people who support President Trump to cause trouble}.  Just like J6, the dims and fbi will cause some big disturbance and blame it on people who will vote for President Trump.   If anyone tries to get you or anyone else you know, to go to any event or protest,  or to threaten the Government in any way.  Know that they are working for biden. Dont Go, Just like J6 where many fbi agents were there, in MAGA hats, encourageing people to use weapons and destroy public property.  Their new plan is to try to fool honest people into thinking MAGA ` `Make America Great` , is a bad thing.   like J6, they are trying to incite violence, and blame MAGA.Tell everyone you know to "Not participate "  in  events , except President Trumps rallys.They have the Fake Media included in this corrupt plan to set you up!President Trump told everyone to stand down and go home on J6,  1/2 hr later the fbi told twitter to take the post down.  they did.Tell all your friends, and please pass this message to everyone..'),
#  ('Patriots for President Trump.biden was told to say “Donald Trump and the MAGA Republicans, represent an extremism that threatens our republic,” .  Dont be tricked by the lies of the democrats.  Their new plan is... {"they have to try to get as many people who support President Trump to cause trouble}.  Just like J6, the dims and fbi will cause some big disturbance and blame it on people who will vote for President Trump.   If anyone tries to get you or anyone else you know, to go to any event or protest,  or to threaten the Government in any way.  Know that they are working for biden. Dont Go, Just like J6 where many fbi agents were there, in MAGA hats, encourageing people to use weapons and destroy public property.  Their new plan is to try to fool honest people into thinking MAGA ` `Make America Great` , is a bad thing.   like J6, they are trying to incite violence, and blame MAGA.Tell everyone you know to "Not participate "  in  events , except President Trumps rallys.They have the Fake Media included in this corrupt plan to set you up!President Trump told everyone to stand down and go home on J6,  1/2 hr later the fbi told twitter to take the post down.  they did.Tell all your friends, and please pass this message to everyone..',
#   'No thanks patriot. Hard pass on what’s on display here.'),
#  ('How do you even start a conversation on this ?! Shame on you fox',
#   "I agree. The idea that as soon as the military discovers something,  that it must let congress know when the military itself doesn't know what it is, any info to help answer questions is NUTS. What the story says is that they discovered it on Jan 27, the president told on the 1st... we can assume congress was told on the 1st too, or the 2nd and then it was leaked to the public.  We live in a hyperpartisan political world where unfortunately,  Congress plays politics with classified information.   The military has the duty to gather all information first to protect the country. If it was a threat, the military scramblesm"),
#  ('Not only tried to conceal it but tried to dodge and say there were balloons during Trumps administration.   Bend over Biden and his socialist regime are the biggest threat to national security',
#   'Chinese spy balloons under Trump not discovered until after Biden took office'),
#  ('Chinese spy balloons under Trump not discovered until after Biden took office',
#   'just like the missing classified documents'),
#  ('just like the missing classified documents',
#   "In Biden's garage? Or the University office?"),
#  ("In Biden's garage? Or the University office?", 'Chinatown'),
#  ("In Biden's garage? Or the University office?", 'Chinatown?'),
#  ('Chinese spy balloons under Trump not discovered until after Biden took office',
#   'Really when did those UNDETECTED balloons float thru our sovereign air space across America over military bases under Trump. And Trump did nothing. When was that'),
#  ('Really when did those UNDETECTED balloons float thru our sovereign air space across America over military bases under Trump. And Trump did nothing. When was that',
#   'Three Chinese Balloons Flew Over US During Trump Presidency'),
#  ('Three Chinese Balloons Flew Over US During Trump Presidency', 'Prove it.'),
#  ('Prove it.', 'They dropped fortune cookies on my front lawn.'),
#  ('Prove it.', 'Wait. Where’s my Sharpie..'),
#  ('Three Chinese Balloons Flew Over US During Trump Presidency',
#   "When. How did the Biden administration find them when they couldn't find one themselves during this administration. Your about sharp as a marble.  How did they find it   if it was UNDETECTED during Trumps administration hahaha too funny"),
#  ('Three Chinese Balloons Flew Over US During Trump Presidency',
#   "Why didn't you report them when you saw them?"),
#  ('Three Chinese Balloons Flew Over US During Trump Presidency',
#   'Dates, and video please'),
#  ('Dates, and video please', 'Google, grampa.'),
#  ('Google, grampa.', 'Google joke. You may see your picture there!!!'),
#  ('Three Chinese Balloons Flew Over US During Trump Presidency',
#   'He was out of office..and no one informed him.'),
#  ('Three Chinese Balloons Flew Over US During Trump Presidency',
#   'Roll the tape'),
#  ('Three Chinese Balloons Flew Over US During Trump Presidency', 'Lies'),
#  ('Chinese spy balloons under Trump not discovered until after Biden took office',
#   "All the evidence was on Hunter's laptop. That's why we never heard about it."),
#  ('Chinese spy balloons under Trump not discovered until after Biden took office',
#   "That's not what your Mom says."),
#  ('Chinese spy balloons under Trump not discovered until after Biden took office',
#   "Not discovered? Or another one of China Joe's fabricated lies. Or just another diversion tactic by the Joe and the Ho regime?"),
#  ('Chinese spy balloons under Trump not discovered until after Biden took office',
#   "That's a lie and you know it."),
#  ('Not only tried to conceal it but tried to dodge and say there were balloons during Trumps administration.   Bend over Biden and his socialist regime are the biggest threat to national security',
#   'Biden falling all over the place, just not off a cliff. I’ll cook a pig Hawaiian style and have a big celebration the day it happens.'),
#  ('Not only tried to conceal it but tried to dodge and say there were balloons during Trumps administration.   Bend over Biden and his socialist regime are the biggest threat to national security',
#   'Biden is the biggest threat to our democracy.'),
#  ('Biden is the biggest threat to our democracy.',
#   'Biden voters are the biggest threat to our democracy because they put him there.'),
#  ('Biden voters are the biggest threat to our democracy because they put him there.',
#   'Even the dead ones.'),
#  ('Biden is the biggest threat to our democracy.',
#   "And the biggest threat to children who don't like being sniffed."),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'Aka ChiComs.'),
#  ('Aka ChiComs.', 'That is their only true name.'),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'How can that be when they said they would be the most inclusive and transparent administration ever???'),
#  ('How can that be when they said they would be the most inclusive and transparent administration ever???',
#   'They lied.'),
#  ('They lied.', 'Ya think?'),
#  ('How can that be when they said they would be the most inclusive and transparent administration ever???',
#   'Lying from Day # One.'),
#  ('How can that be when they said they would be the most inclusive and transparent administration ever???',
#   'and you believed them?'),
#  ('How can that be when they said they would be the most inclusive and transparent administration ever???',
#   "Apparently you have yet to watch Karine Jean- Pierrre as she makes every thing perfectly clear. She's still on the fence as to the balloon issue."),
#  ("Apparently you have yet to watch Karine Jean- Pierrre as she makes every thing perfectly clear. She's still on the fence as to the balloon issue.",
#   'You mean Cabbage Patch Pierre.'),
#  ('How can that be when they said they would be the most inclusive and transparent administration ever???',
#   'They lie, like always'),
#  ('How can that be when they said they would be the most inclusive and transparent administration ever???',
#   "They don't lie all the time.  It's just when their lips are moving, or their fingers are typing."),
#  ("They don't lie all the time.  It's just when their lips are moving, or their fingers are typing.",
#   'You give them more credit than I do.'),
#  ('How can that be when they said they would be the most inclusive and transparent administration ever???',
#   'Only to our chicom enemies.'),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'Of course China Joe wants to hide the Chinese Spy Balloon, we do not expect anything different from Joe or Hunter who takes a regular paycheck from China.....XI WOULD BE SO PROUD....'),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'Much better than the last Insurrectionist one.'),
#  ('Much better than the last Insurrectionist one.',
#   'To call Jan 6 an insurrection is fabrication of hyperbole.'),
#  ('Much better than the last Insurrectionist one.',
#   'Insurrection? Lol lol ok Miss, what’s happening at the border is insurrection that’s why Texas is going to remove Biden from there ballot'),
#  ('Much better than the last Insurrectionist one.', 'Who was that?'),
#  ('Much better than the last Insurrectionist one.',
#   'Even if that was an insurrection and Trump was responsible, it didn’t nor could it have, caused as much damage as the Biden Family has caused this country, with their shady foreign “business” dealings! We have yet to see the full repercussions of the Bidens selling our military secrets to communists.'),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'More like treason'),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'Also deception and if you don’t believe it you are deceiving yourself'),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'Add this to our unsecured border and this is the act of a insurrectionist or a TRAITOR? Not Jan.6th.....'),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'That’s OCC.'),
#  ('Americans know 100% this is the Administration of Obstruction, Collusion, and Corruption.',
#   'And there are still thumbs downers anyways'),
#  ("And when they couldn't conceal it, they tried to justify it by saying it had happened several times during the trump administration.",
#   'The Biden Woke Air Force got caught and the Flag Officers LIED'),
#  ('The Biden Woke Air Force got caught and the Flag Officers LIED',
#   'What happened to the Space Force?'),
#  ('What happened to the Space Force?',
#   'Why would they get involved. A balloon is an AIR CRAFT.'),
#  ('Why would they get involved. A balloon is an AIR CRAFT.',
#   'It was 65,000 FEET IN THE AIR.'),
#  ('It was 65,000 FEET IN THE AIR.',
#   'The ministry of truth Bah ha ha ha ha Out of business'),
#  ('It was 65,000 FEET IN THE AIR.', 'Your point?'),
#  ('It was 65,000 FEET IN THE AIR.',
#   'Yeah....and airline pilots reported seeing this ONE, but NONE while Trump was Prez.'),
#  ('It was 65,000 FEET IN THE AIR.',
#   'Space Force handles things that are in orbit.'),
#  ('What happened to the Space Force?', 'It is still being built'),
#  ('It is still being built',
#   'Space Force is in full operation deploying the Space Plane last month, and Elon launched one their weapons platform into orbit.'),
#  ('What happened to the Space Force?',
#   'Since it was Trumps idea Brandon probably canceled it'),
#  ('What happened to the Space Force?',
#   'Of the ministry of truth ???🤣🤣🤣🤡🤣🤡🤡🤡🤣🤣'),
#  ('What happened to the Space Force?',
#   "Well, you  know....Joey is in charge of them now, so they don't matter to liberals."),
#  ('What happened to the Space Force?',
#   'It just launched a weapons platform into Space. Also they just put the Space Plane in orbit again.'),
#  ('What happened to the Space Force?',
#   'Truthful Joe in 2020, “I will have the most transparent presidency in history”…'),
#  ('What happened to the Space Force?',
#   'Joe disbanded the space force and replaced it with a Military Marching Band.'),
#  ('The Biden Woke Air Force got caught and the Flag Officers LIED',
#   'Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   '🤪'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   "So you are saying there wasn't a Chinese spy balloon shot down over America? ok got it..."),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'Im guessing your daddy took your participation trophy away from you so you only trust liberals now.  You will heal and see the light eventually.'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'CNN paid that high school student that much? I’ll bet he’s popular with the ladies.'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   "What about NBC, CNN, the WP all having to reach a settlement with Nicholas Sandmann.  What about all of them admitting that Hunter's laptop was legit after claiming it was all a Russian hoax. Those are only 2 examples there are many more.  Don't point fingers at FOX with out pointing at your own so-called media."),
#  ("What about NBC, CNN, the WP all having to reach a settlement with Nicholas Sandmann.  What about all of them admitting that Hunter's laptop was legit after claiming it was all a Russian hoax. Those are only 2 examples there are many more.  Don't point fingers at FOX with out pointing at your own so-called media.",
#   "If you have verifiable evidence of Biden corruption, please rush it off to a court of law. NOT hearsay (disgruntled businessman Bobulinski) or Fox innuendo, paid “whistle-blowers”, selective emails, logs and bank accounts. As for Hunter Biden's laptop, it has been highly compromised since cokehead Hunter lost control of it, and not least by MacIsaac who downloaded sections of it.\xa0 At this stage Hunter has been charged with a gun felony and tax issues and will pay a large fine. Trump will likely take a plea deal for obstruction of justice. Perhaps then we can all get back to dealing with our real enemies: China, Russia, and Iran."),
#  ("If you have verifiable evidence of Biden corruption, please rush it off to a court of law. NOT hearsay (disgruntled businessman Bobulinski) or Fox innuendo, paid “whistle-blowers”, selective emails, logs and bank accounts. As for Hunter Biden's laptop, it has been highly compromised since cokehead Hunter lost control of it, and not least by MacIsaac who downloaded sections of it.\xa0 At this stage Hunter has been charged with a gun felony and tax issues and will pay a large fine. Trump will likely take a plea deal for obstruction of justice. Perhaps then we can all get back to dealing with our real enemies: China, Russia, and Iran.",
#   'I think your feelings are going to be hurt BIG time. 😂😂😂😂'),
#  ('I think your feelings are going to be hurt BIG time. 😂😂😂😂',
#   'Five long years- WAKE UP MURDOCH AND TRUMP HAVE CONNED YOU!'),
#  ("If you have verifiable evidence of Biden corruption, please rush it off to a court of law. NOT hearsay (disgruntled businessman Bobulinski) or Fox innuendo, paid “whistle-blowers”, selective emails, logs and bank accounts. As for Hunter Biden's laptop, it has been highly compromised since cokehead Hunter lost control of it, and not least by MacIsaac who downloaded sections of it.\xa0 At this stage Hunter has been charged with a gun felony and tax issues and will pay a large fine. Trump will likely take a plea deal for obstruction of justice. Perhaps then we can all get back to dealing with our real enemies: China, Russia, and Iran.",
#   'We could deal with those enemies now if this administration would close the border. Liberals think everyone crossing illegally is a refugee from Mexico, Central & South America.'),
#  ('We could deal with those enemies now if this administration would close the border. Liberals think everyone crossing illegally is a refugee from Mexico, Central & South America.',
#   'Tell your Rich Republicans- they have no desire to Close the border'),
#  ("If you have verifiable evidence of Biden corruption, please rush it off to a court of law. NOT hearsay (disgruntled businessman Bobulinski) or Fox innuendo, paid “whistle-blowers”, selective emails, logs and bank accounts. As for Hunter Biden's laptop, it has been highly compromised since cokehead Hunter lost control of it, and not least by MacIsaac who downloaded sections of it.\xa0 At this stage Hunter has been charged with a gun felony and tax issues and will pay a large fine. Trump will likely take a plea deal for obstruction of justice. Perhaps then we can all get back to dealing with our real enemies: China, Russia, and Iran.",
#   "It's getting there, that is why Congress is looking at impeachment!"),
#  ("It's getting there, that is why Congress is looking at impeachment!",
#   'Five long years- WAKE UP MURDOCH AND TRUMP HAVE CONNED YOU!'),
#  ("If you have verifiable evidence of Biden corruption, please rush it off to a court of law. NOT hearsay (disgruntled businessman Bobulinski) or Fox innuendo, paid “whistle-blowers”, selective emails, logs and bank accounts. As for Hunter Biden's laptop, it has been highly compromised since cokehead Hunter lost control of it, and not least by MacIsaac who downloaded sections of it.\xa0 At this stage Hunter has been charged with a gun felony and tax issues and will pay a large fine. Trump will likely take a plea deal for obstruction of justice. Perhaps then we can all get back to dealing with our real enemies: China, Russia, and Iran.",
#   'So you need evidence and eyewitness testimony, written documents, government logs, and financial information recorded and retained by private banks does not count....  so what you need is some sleezy congressman to say that they have documents proving biden is a crook and you would believe it.Trump will not accept any plea deal.  Given the locale where the trials are being held, he will probably be convicted and then win on appeal.'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'So you missed the part about NBC News Reporting.'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   '“ The steel dossier “4 years of liesNo journalism No research Just lies'),
#  ('“ The steel dossier “4 years of liesNo journalism No research Just lies',
#   "There are many unanswered questions, yet the public won't demand answers: Who is Biden's controller?Who is on the Epstein client List, all the people, not selectively removing names?How many people were killed, raped and robbed by the Illegal Aliens?Provide a updated list of all the media, by company, their financial investments in CCP?Would we have had Covid if Hillary was elected?The Fraud in Stimulus Spending Programs?Why are the FBI & DOJ politically targeting Christians as “Domestic Terrorists?"),
#  ('“ The steel dossier “4 years of liesNo journalism No research Just lies',
#   'Yep Don Jr and Mike Flynn did Not meet with Russian Spies??/'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   '“ hands up don’t shoot”🤣🤣🤣🤣🤣🤣🤣🤣🤣'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'Stop reading and commenting.'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'So how did the cowpie taste?'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'Then why is it outperforming all other MSM outlets ...combined.Why are you here?'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'If you consider the GOP a Joke, you must be loyal to President Xi'),
#  ('The Biden Woke Air Force got caught and the Flag Officers LIED',
#   'They just follow the lead of their Liar and Chief Joe Biden.'),
#  ('The Biden Woke Air Force got caught and the Flag Officers LIED',
#   'this post violated our policy'),
#  ('this post violated our policy', 'So you are employed by the DNC.'),
#  ('So you are employed by the DNC.', 'Truth Hurt Rurts?'),
#  ('Truth Hurt Rurts?', 'Not at all, sure gets your goat though.'),
#  ('this post violated our policy',
#   'So you know this because you work for the Chinese government right?'),
#  ('So you know this because you work for the Chinese government right?',
#   'Basic science and i read the news- you should try it?'),
#  ('Basic science and i read the news- you should try it?',
#   '😂 Basic science is knowing there are only two genders. So don’t pretend democrats know anything about science'),
#  ('😂 Basic science is knowing there are only two genders. So don’t pretend democrats know anything about science',
#   'George Santos?🥸?'),
#  ('this post violated our policy',
#   'Check out all yourDownvotes. Your news station msnbc doesn’t have A thumbs down count anymore. You might have better luck on their censored comment section'),
#  ('this post violated our policy',
#   'So why not shoot it down when it was over Alaska instead of letting it float across our entire nation gathering our nuclear intelligence first? This is just another Biden failure.'),
#  ('So why not shoot it down when it was over Alaska instead of letting it float across our entire nation gathering our nuclear intelligence first? This is just another Biden failure.',
#   'Nope- Nobody expected it to keep drifting. They have appeared over American airspace before. As i tried to explain- Even over Alaska it could have drifted for miles once the balloon was deflated, and when it eventually crashed it would be lethal.- I guess Science was not your best subject at school trumpgirl?'),
#  ('Nope- Nobody expected it to keep drifting. They have appeared over American airspace before. As i tried to explain- Even over Alaska it could have drifted for miles once the balloon was deflated, and when it eventually crashed it would be lethal.- I guess Science was not your best subject at school trumpgirl?',
#   "It didn't drift anywhere, it went over our military assets."),
#  ("It didn't drift anywhere, it went over our military assets.",
#   'It went over the whole country- not just those- it was blocked and shot down safely at sea'),
#  ('It went over the whole country- not just those- it was blocked and shot down safely at sea',
#   'It went over on a course that took it to every critical base we have.'),
#  ("And when they couldn't conceal it, they tried to justify it by saying it had happened several times during the trump administration.",
#   "Does that shock you? But since nothing Trump does shocks you MAGAs I wouldn't worry about a single Biden incident."),
#  ("Does that shock you? But since nothing Trump does shocks you MAGAs I wouldn't worry about a single Biden incident.",
#   'Life was much better then and everyone knows it.  Joe blows'),
#  ('Life was much better then and everyone knows it.  Joe blows',
#   'You never had it so good as you do now.'),
#  ('You never had it so good as you do now.',
#   'Then how do you explain the extreme price of groceries now versus then?'),
#  ('Then how do you explain the extreme price of groceries now versus then?',
#   'You don’t like Ramen?'),
#  ('Life was much better then and everyone knows it.  Joe blows',
#   'You mean when I couldn’t buy toilet paper, cheap didn’t help because there was no where to travel, and we lost 1 million Americans to a virus?  Now we know that Truth mp’s voter fraud claims actually became him denying his loss and trying to pressure states into lying about the fraud.Sorry, attempting to overturn an election 🗳️ s against our Constitution…/you “patriots” know that!'),
#  ("Does that shock you? But since nothing Trump does shocks you MAGAs I wouldn't worry about a single Biden incident.",
#   '🤪'),
#  ("Does that shock you? But since nothing Trump does shocks you MAGAs I wouldn't worry about a single Biden incident.",
#   'MAGA Make America Great Again!  Democrat give us everything you have and we may let you live.'),
#  ("Does that shock you? But since nothing Trump does shocks you MAGAs I wouldn't worry about a single Biden incident.",
#   "It's funny how the left can't post anything anymore without including the make America great again slogan. MAGA!"),
#  ("Does that shock you? But since nothing Trump does shocks you MAGAs I wouldn't worry about a single Biden incident.",
#   'So Biden letting in terrorists through our swiss cheese non existent border is nothing to worry about. Got it.'),
#  ("Does that shock you? But since nothing Trump does shocks you MAGAs I wouldn't worry about a single Biden incident.",
#   'And it only happened once because Joe said it did. Yep.'),
#  ("And when they couldn't conceal it, they tried to justify it by saying it had happened several times during the trump administration.",
#   'No matter how much someone doesnt like trump, he didnt pull anything close to selling out this country to our enemy.  Biden and all the people he put in place are traitors.'),
#  ('No matter how much someone doesnt like trump, he didnt pull anything close to selling out this country to our enemy.  Biden and all the people he put in place are traitors.',
#   'Our defense department is like the White House. People cannot trust what comes out of either. I can’t think of any government agency that can be trusted. I’m convinced that it’s impossible to attract our homeland because of the 2nd amendment, not because of the DOD.'),
#  ('No matter how much someone doesnt like trump, he didnt pull anything close to selling out this country to our enemy.  Biden and all the people he put in place are traitors.',
#   'How did Biden sell out the U.S. to China?  Trump using his cronies to block aid to Ukraine and being endorsed by Putin.'),
#  ('How did Biden sell out the U.S. to China?  Trump using his cronies to block aid to Ukraine and being endorsed by Putin.',
#   'Oh gee, other  than he and Hunter are owned by the CCP ?'),
#  ('How did Biden sell out the U.S. to China?  Trump using his cronies to block aid to Ukraine and being endorsed by Putin.',
#   'Your problem is that you keep watching CNN. Well, at least they have 1 viewer left.'),
#  ('How did Biden sell out the U.S. to China?  Trump using his cronies to block aid to Ukraine and being endorsed by Putin.',
#   'Obama let Putin have Crimea while Hunter was making private business deals with the CCP while Biden was VP.Biden was busy blackmailing the Ukrainians to stop investigating Burisma. Next question.'),
#  ('Obama let Putin have Crimea while Hunter was making private business deals with the CCP while Biden was VP.Biden was busy blackmailing the Ukrainians to stop investigating Burisma. Next question.',
#   'while Santa was stealing all the gifts'),
#  ('while Santa was stealing all the gifts',
#   "NORAD can track Santa but somehow missed a Chinese spy balloon crossing Canada Biden failing to do this was Trump's fault."),
#  ('How did Biden sell out the U.S. to China?  Trump using his cronies to block aid to Ukraine and being endorsed by Putin.',
#   'Members of the House are not Trump’s cronies.'),
#  ('Members of the House are not Trump’s cronies.',
#   'Yes they are- some of them proudly declare how they ring Trump all of the time- many are bought and paid for'),
#  ('How did Biden sell out the U.S. to China?  Trump using his cronies to block aid to Ukraine and being endorsed by Putin.',
#   'Barry and Joey gave Crimea to Putin. Remember that?'),
#  ('How did Biden sell out the U.S. to China?  Trump using his cronies to block aid to Ukraine and being endorsed by Putin.',
#   "Gee, who ended up with how much of our Plutonium?  Putin.  How'd he get it?  The Clintons.  That's who Putin is allies with."),
#  ('No matter how much someone doesnt like trump, he didnt pull anything close to selling out this country to our enemy.  Biden and all the people he put in place are traitors.',
#   'BRAVO..BRAVO..You nailed it Sir.'),
#  ('No matter how much someone doesnt like trump, he didnt pull anything close to selling out this country to our enemy.  Biden and all the people he put in place are traitors.',
#   'What about the TS/SCI documents he stole and lied about.  Who knows who had access to those.'),
#  ('What about the TS/SCI documents he stole and lied about.  Who knows who had access to those.',
#   'We know the Chicoms had access to bidung’s “hidden in plain sight” secret docs.'),
#  ('We know the Chicoms had access to bidung’s “hidden in plain sight” secret docs.',
#   "And the documents Trump had in the public ballroom?  Same.  Or the doc's in the bathroom?"),
#  ("And the documents Trump had in the public ballroom?  Same.  Or the doc's in the bathroom?",
#   'Don’t forget Penn State, Chinatown, and his garage floor.No former president guards on his home nor in locked vaults.The garage???? “Come on man!”No presidential authority to have, nor take them.And the list goes on, but nothing as small as Trump’s home invasion was ever completed on the numerous public places bidung lost his records at.But Hey, Mar a lago was fully secured by secret service controlling access 24/7Where was bidung’s security from back over a decade In all those  REALLY public places.If you are going to speak on this forum, get the facts straight and tell ALL of them, not just the ones to make your post  FAKE NEWS!'),
#  ('Don’t forget Penn State, Chinatown, and his garage floor.No former president guards on his home nor in locked vaults.The garage???? “Come on man!”No presidential authority to have, nor take them.And the list goes on, but nothing as small as Trump’s home invasion was ever completed on the numerous public places bidung lost his records at.But Hey, Mar a lago was fully secured by secret service controlling access 24/7Where was bidung’s security from back over a decade In all those  REALLY public places.If you are going to speak on this forum, get the facts straight and tell ALL of them, not just the ones to make your post  FAKE NEWS!',
#   "Nope Ricky several people have contravened the Presidential Records Act (1978) but the Act does not include a criminal penalty for removing or destroying these records. However, by designating presidential records the property of the U.S. government, noncompliance can trigger other criminal laws. These include the Federal Records Act, the Freedom of Information Act, the National Archives and Records Administration's regulations and Section 1924 of Title 18 of the U.S. Crimes and Criminal Procedure Code. Most people involved, including Mike Pence,\xa0 David Petraeus, Pete Navarro, Sandy Berger, and John Poindexter, fully cooperated, and have generally been warned and/or fined.Obstruction of Justice under s793(e) of the Espionage Act (1917) is another matter…"),
#  ("Nope Ricky several people have contravened the Presidential Records Act (1978) but the Act does not include a criminal penalty for removing or destroying these records. However, by designating presidential records the property of the U.S. government, noncompliance can trigger other criminal laws. These include the Federal Records Act, the Freedom of Information Act, the National Archives and Records Administration's regulations and Section 1924 of Title 18 of the U.S. Crimes and Criminal Procedure Code. Most people involved, including Mike Pence,\xa0 David Petraeus, Pete Navarro, Sandy Berger, and John Poindexter, fully cooperated, and have generally been warned and/or fined.Obstruction of Justice under s793(e) of the Espionage Act (1917) is another matter…",
#   'Yep, bidung’s quilty!No doubt about it.'),
#  ('No matter how much someone doesnt like trump, he didnt pull anything close to selling out this country to our enemy.  Biden and all the people he put in place are traitors.',
#   'you must be talking about all the secret\xa0meetings with putin were the evidence was destroyed'),
#  ('you must be talking about all the secret\xa0meetings with putin were the evidence was destroyed',
#   'Plutonium, baby, is all I have to say.'),
#  ('No matter how much someone doesnt like trump, he didnt pull anything close to selling out this country to our enemy.  Biden and all the people he put in place are traitors.',
#   'Actually, they are treasoners!'),
#  ('No matter how much someone doesnt like trump, he didnt pull anything close to selling out this country to our enemy.  Biden and all the people he put in place are traitors.',
#   'Joe says that’s a lie.'),
#  ("And when they couldn't conceal it, they tried to justify it by saying it had happened several times during the trump administration.",
#   "It did. Trump did not even read his Intel reports. He was too busy Tweet fighting with Rosie O'Donnell."),
#  ("It did. Trump did not even read his Intel reports. He was too busy Tweet fighting with Rosie O'Donnell.",
#   'You think THIS ONE reads his?'),
#  ('You think THIS ONE reads his?', 'ROFLMBO nailed him!'),
#  ('ROFLMBO nailed him!', '🎯🎯🎯🎯🎯'),
#  ('You think THIS ONE reads his?', 'No, but he does drool on them.'),
#  ("It did. Trump did not even read his Intel reports. He was too busy Tweet fighting with Rosie O'Donnell.",
#   'Hope you can get over your TDS someday'),
#  ("It did. Trump did not even read his Intel reports. He was too busy Tweet fighting with Rosie O'Donnell.",
#   'Did’t you post you wanted to be Bidens monica?'),
#  ("It did. Trump did not even read his Intel reports. He was too busy Tweet fighting with Rosie O'Donnell.",
#   'BURP.'),
#  ("It did. Trump did not even read his Intel reports. He was too busy Tweet fighting with Rosie O'Donnell.",
#   'Whether or not that is true, it would be a stretch to think Trump is well read. I doubt he has read even one book in the past decade.'),
#  ('Whether or not that is true, it would be a stretch to think Trump is well read. I doubt he has read even one book in the past decade.',
#   'I wonder if he graduated higher than fourth from last in his class and got busted for plagiarism though . One things for sure, he can’t spin a fanciful yarn like Joe.'),
#  ('Whether or not that is true, it would be a stretch to think Trump is well read. I doubt he has read even one book in the past decade.',
#   'Your Point is?'),
#  ("It did. Trump did not even read his Intel reports. He was too busy Tweet fighting with Rosie O'Donnell.",
#   "Yet he is far more successful than you will ever be. You can't even post under your real name.Yes, I DO use my real name to post comments"),
#  ("Yet he is far more successful than you will ever be. You can't even post under your real name.Yes, I DO use my real name to post comments",
#   "Well ain't you special."),
#  ("It did. Trump did not even read his Intel reports. He was too busy Tweet fighting with Rosie O'Donnell.",
#   'Bedford the intel expert. Not'),
#  ("And when they couldn't conceal it, they tried to justify it by saying it had happened several times during the trump administration.",
#   'And Brandon still got his 10%'),
#  ("And when they couldn't conceal it, they tried to justify it by saying it had happened several times during the trump administration.",
#   'If balloons were sent over during the Trump administration, he was not told about it (which is what he claims).  Would he have let it float over Alaska and the entire continental United States?  I think not.'),
#  ('If balloons were sent over during the Trump administration, he was not told about it (which is what he claims).  Would he have let it float over Alaska and the entire continental United States?  I think not.',
#   'Opinions vary.'),
#  ('Opinions vary.', 'Maybe, but the smart money says he would not.'),
#  ('Opinions vary.', 'Not true.  Trump would have splashed it.'),
#  ('Opinions vary.', 'Go back to watching road house.'),
#  ('Opinions vary.', 'How many do you have?'),
#  ('If balloons were sent over during the Trump administration, he was not told about it (which is what he claims).  Would he have let it float over Alaska and the entire continental United States?  I think not.',
#   'One thing we do know for sure....if the woke military HAD told Trump about something like this happening and he did nothing Biden and his military would have splashed it all over the front pages of liberal media to try to cover for Joey.'),
#  ('One thing we do know for sure....if the woke military HAD told Trump about something like this happening and he did nothing Biden and his military would have splashed it all over the front pages of liberal media to try to cover for Joey.',
#   'they did'),
#  ('they did',
#   'Not at the time, and only after Biden was subjected to criticism.  Not only that, the Democrats and the liberals Obama installed into the military would have TOLD ON DAY ONE, not a few years later.  Got that?'),
#  ('Not at the time, and only after Biden was subjected to criticism.  Not only that, the Democrats and the liberals Obama installed into the military would have TOLD ON DAY ONE, not a few years later.  Got that?',
#   '👍exactly'),
#  ('Not at the time, and only after Biden was subjected to criticism.  Not only that, the Democrats and the liberals Obama installed into the military would have TOLD ON DAY ONE, not a few years later.  Got that?',
#   'Trump appointed Miley.'),
#  ('Trump appointed Miley.',
#   'Do you have anything other than but, but Trump?  Is your TDS truly that severe?'),
#  ('Do you have anything other than but, but Trump?  Is your TDS truly that severe?',
#   "Amused. I voted for the guy twice and will again.  I'm just stating the facts."),
#  ('Trump appointed Miley.',
#   'On an amusing note, I find it odd that NORAD can tell us exactly where Santa Claus is but not that balloon. when it was visible by eye.'),
#  ('they did',
#   'LOL only years later as a deflection from Joe Biden’s sheer incompetence, you are the party of whataboutism.'),
#  ('If balloons were sent over during the Trump administration, he was not told about it (which is what he claims).  Would he have let it float over Alaska and the entire continental United States?  I think not.',
#   'Based on his track record he would have made the wrong decision then blame someone else by lying.'),
#  ('Based on his track record he would have made the wrong decision then blame someone else by lying.',
#   'thank you for explaining exactly what Biden did.'),
#  ('thank you for explaining exactly what Biden did.', "It's what they all do"),
#  ('Based on his track record he would have made the wrong decision then blame someone else by lying.',
#   'Surely you’re talking about biden….'),
#  ('Based on his track record he would have made the wrong decision then blame someone else by lying.',
#   "You're talking about Joey again....tsk tsk..."),
#  ('Based on his track record he would have made the wrong decision then blame someone else by lying.',
#   "You mean like you're doing here sweetie?"),
#  ('Based on his track record he would have made the wrong decision then blame someone else by lying.',
#   "Trump stopped a whole lot more people at the border.  Why wouldn't he stop then in the air.  Open Borders Biden probably agreed to let China spy as they're the JV team as Obamer said, right?"),
#  ("Trump stopped a whole lot more people at the border.  Why wouldn't he stop then in the air.  Open Borders Biden probably agreed to let China spy as they're the JV team as Obamer said, right?",
#   'He also killed 500 of Russian special forces in Syria. That was awesome.'),
#  ('Based on his track record he would have made the wrong decision then blame someone else by lying.',
#   'He did, and then blamed Trump.'),
#  ('If balloons were sent over during the Trump administration, he was not told about it (which is what he claims).  Would he have let it float over Alaska and the entire continental United States?  I think not.',
#   'There were rumblings of insurrections against President Trump/'),
#  ('There were rumblings of insurrections against President Trump/',
#   'Correct, the only insurrection that happened during the Trump Administration was the political class rebelling against an outsider (TRUMP)| coming in to expose their TREASON!!!  He is going to viciously savage them this time, rightfully so.'),
#  ('If balloons were sent over during the Trump administration, he was not told about it (which is what he claims).  Would he have let it float over Alaska and the entire continental United States?  I think not.',
#   'What does Trump have to do with it?'),
#  ('If balloons were sent over during the Trump administration, he was not told about it (which is what he claims).  Would he have let it float over Alaska and the entire continental United States?  I think not.',
#   "NORAD computers were programed to ignore 'natural' blips - Flocks of birds, etc., that did not indicate planes and missiles. Consequently, balloons moving with the speed of the wind were also ignored. After the balloon scandal, NORAD computer records were examined, showing previous likely balloon flights. (Or that was the story) So, we changed our parameters and shot down a high school science project over the Great Lakes with a half million dollar missile!"),
#  ("NORAD computers were programed to ignore 'natural' blips - Flocks of birds, etc., that did not indicate planes and missiles. Consequently, balloons moving with the speed of the wind were also ignored. After the balloon scandal, NORAD computer records were examined, showing previous likely balloon flights. (Or that was the story) So, we changed our parameters and shot down a high school science project over the Great Lakes with a half million dollar missile!",
#   "During the Korean War, we used to watch and track Russian missiles from radar sites in Japan as they were fired up from Vladivostok  Russia. As they ascended their lateral movement was very slow, and as they moved laterally, 1000+ We also tracked and plotted flights of birds, ships, and on occasion railroad trains.  Hopefully, we haven't forgotten  the lesson from Pearl Harbor when we reportedly mistook the  Japanese invasion aircraft as ours. But then that was a democrat administration too."),
#  ("During the Korean War, we used to watch and track Russian missiles from radar sites in Japan as they were fired up from Vladivostok  Russia. As they ascended their lateral movement was very slow, and as they moved laterally, 1000+ We also tracked and plotted flights of birds, ships, and on occasion railroad trains.  Hopefully, we haven't forgotten  the lesson from Pearl Harbor when we reportedly mistook the  Japanese invasion aircraft as ours. But then that was a democrat administration too.",
#   "The US military doesn't change all it's personnel with each new president, so Democrat or Repubican doesn't have anything to do with it."),
#  ("The US military doesn't change all it's personnel with each new president, so Democrat or Repubican doesn't have anything to do with it.",
#   "You gotta be kidding! The entire military has a new Commander In Chief with each new President. No need to change a single G.I. to turn the military on it's head, hit the brakes, mash the accelerator or shift into reverse."),
#  ("You gotta be kidding! The entire military has a new Commander In Chief with each new President. No need to change a single G.I. to turn the military on it's head, hit the brakes, mash the accelerator or shift into reverse.",
#   "The context was japanese aircraft being mistaken for our own because it was a Democrat administration. This is absurd. The politics of the president doesn't change how the radar operator does his job. Military personell are military first, not party operatives."),
#  ("The context was japanese aircraft being mistaken for our own because it was a Democrat administration. This is absurd. The politics of the president doesn't change how the radar operator does his job. Military personell are military first, not party operatives.",
#   'I agree when it comes to defense - My thoughts pertained to offense.'),
#  ("During the Korean War, we used to watch and track Russian missiles from radar sites in Japan as they were fired up from Vladivostok  Russia. As they ascended their lateral movement was very slow, and as they moved laterally, 1000+ We also tracked and plotted flights of birds, ships, and on occasion railroad trains.  Hopefully, we haven't forgotten  the lesson from Pearl Harbor when we reportedly mistook the  Japanese invasion aircraft as ours. But then that was a democrat administration too.",
#   'The 9/11 Attack was a GOP Administration. The Wuhan China Flu Attack was under Trump. In \'68 the Paris Peace Talks were sabotaged during the LBJ Administration, extending the war and killing 30,000 more of our boys.  But the Talks were secretly sabotaged by Nixon so that one is a wash, amirite? Can I get a "Touché!!!", bevoa?'),
# ...
#   "We know this. It's not a secret. But that doesn't mean the spy craft was not up to no good."),
#  ('Biden promised transparency. He lied, of course.',
#   'He thought the ballon was transparent'),
#  ("Do they mean like when the Trump administration let multiple chinese balloons pass over the country without shooting them down and didn't tell anyone?",
#   "Never happened! You wouldn't have known about it if it did, unless....., is this Joe Biden?"),
#  ("Never happened! You wouldn't have known about it if it did, unless....., is this Joe Biden?",
#   "Gee, you never heard about it huh? Thanks for proving my point.You can lead a horse to water, but you can't make him think."),
#  ("Do they mean like when the Trump administration let multiple chinese balloons pass over the country without shooting them down and didn't tell anyone?",
#   'You guys are so, so desperate.'),
#  ('You guys are so, so desperate.',
#   'Such ignorant comments from MAGAts while the President continues to do a good job. The economy added 13.9 M jobs, putting the total 4.5 M higher than before the pandemic…BLS The unemployment rate dropped for a time to 3.4%,\xa0 the lowest in nearly 54 years; unfilled job openings surged, with 3 jobs for every 2 unemployed job seekers…BLS Defying economists who have been predicting a recession for more than a year, the economy expanded at an annual rate of 5.2% in the 3rd quarter…BEA The Labor Force Participation rate is up 1.5% Manufacturing jobs have gone up by 815,000 Both the number and rate of violent crimes, including murders specifically, have gone down…FBI Defying economists who have been predicting a recession for more than a year, the economy expanded at an annual rate of 3.9% in the 3rd quarter…BEA Home prices have risen 29.6%. Food stamp recipients have gone down 2% Corporate profits set new annual records in 2021 and 2022…BEA Census said that the fully refundable child tax credit had prevented about 5.3 million children from falling into poverty in 2021. Those lacking health insurance went down by 1.3 percentage points…US Census U.S. crude oil production is up 10.7%; imports are up 7.4%. The US accepted 60,014 refugees in fiscal year 2023…US State Dept. 36 US Court of Appeals judges, 110\xa0 District Court Judges, 4\xa0 US Court of Federal Claims judges, and 2 US Court of International Trade judges confirmations Passed the American Rescue Plan Passed the bipartisan infrastructure bill'),
#  ("Do they mean like when the Trump administration let multiple chinese balloons pass over the country without shooting them down and didn't tell anyone?",
#   'And you know that how? Because Biden told you when he got caught? How did they know if any pass over the country when they said that they were undetected?'),
#  ('And you know that how? Because Biden told you when he got caught? How did they know if any pass over the country when they said that they were undetected?',
#   'Read the report.'),
#  ('Read the report.', 'Report written by who? Brandon’s administration?'),
#  ('Report written by who? Brandon’s administration?',
#   "Pentagon military commanders aren't appointed Einstein."),
#  ("Pentagon military commanders aren't appointed Einstein.",
#   'Are you talking about the same pentagon that gen milley was in charge and called china behind Trump’s back?'),
#  ('I would think the fact that someone did not inform the president until 6 days after they spotted the balloon means our intelligence agencies are negligent in there duty or Biden is not running the country.',
#   'Or Biden etc got away with allowing Chinas espionage.'),
#  ('I would think the fact that someone did not inform the president until 6 days after they spotted the balloon means our intelligence agencies are negligent in there duty or Biden is not running the country.',
#   'Biden is definitely not running this country. He doesn’t even know the difference between his wife and her sister or even what day it is'),
#  ('I would think the fact that someone did not inform the president until 6 days after they spotted the balloon means our intelligence agencies are negligent in there duty or Biden is not running the country.',
#   "Who told you they didn't inform him?  Like talking to a rock."),
#  ("Obama just won't go away! He wanted to fundamentally change America. He won.",
#   'Maybe, he might have outsmarted himself. Now that he’s a wealthy oligarch, he looks worried that his radical leftist base might want to seize his wealth.'),
#  ('Is there anything we can trust about our government?',
#   'No.  Not with this present Clown Administration!'),
#  ('Is there anything we can trust about our government?',
#   'Why of course. You can trust that there will more spending, more debt, more fleecing of America and more taxes.'),
#  ('Did China still give him his 10%?',
#   'You bet they did.  No doubt  Hunter and Milley made a threatening call to China together if they didn’t pay.'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   "vs cnn?  You're a joke. A muted one."),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'No. Stop posting here.'),
#  ('Fox news is news in the same way cowpies are pies. Stop believing a news organization that paid almost $1B in defamation penalties.',
#   'Yes, because everyone should be listening to the state run media outlets that have accumulated Trillions of dollars in defamation penalties.....ok, got it....'),
#  ('Then they invite him to San Francisco for a fiesta',
#   'And the msm frames it so differently'),
#  ('Another example of the socialist Biden Administration lying to the American people.  For God’s sake man tell the truth for a change!!!!',
#   'Your right but they will never speak the truth.'),
#  ('Another example of the socialist Biden Administration lying to the American people.  For God’s sake man tell the truth for a change!!!!',
#   'Biden is the enemy.'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'Because Biden works for the Chinese so does the Democrat party'),
#  ('Because Biden works for the Chinese so does the Democrat party',
#   'Yep, millions of dollars, diamonds and cars to the Biden family.'),
#  ('Because Biden works for the Chinese so does the Democrat party',
#   "I don't know about that but the Biden administration and CCP share the same ideology."),
#  ("I don't know about that but the Biden administration and CCP share the same ideology.",
#   'And personal bank accounts.'),
#  ("I don't know about that but the Biden administration and CCP share the same ideology.",
#   "That's not just a coincidence."),
#  ('Because Biden works for the Chinese so does the Democrat party',
#   'You said it!'),
#  ('Because Biden works for the Chinese so does the Democrat party',
#   'All on the take sice the 1990s.'),
#  ('Because Biden works for the Chinese so does the Democrat party',
#   'Chips and Science Act says your wrong.'),
#  ('Chips and Science Act says your wrong.',
#   'So China is following US law and not stealing IP?'),
#  ('So China is following US law and not stealing IP?',
#   "Biden's Chips and Science law is an anti-China law."),
#  ("Biden's Chips and Science law is an anti-China law.",
#   'And that will stop them from stealing our IP?'),
#  ('Because Biden works for the Chinese so does the Democrat party',
#   "So true. Bill Clinton did the same thing when he was president. Hasn't stopped this party the least bit."),
#  ('Because Biden works for the Chinese so does the Democrat party',
#   'Right.  So do the 81 million voters that voted for him.They are all on the take.  Paid by China.And they are all getting a raise in 2024!'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'because joe bribem is belolden to china'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'Because Joe is there partner'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'Yep'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'there is no doubt they tried to keep this secret so the public would not discover their incompetence'),
#  ('there is no doubt they tried to keep this secret so the public would not discover their incompetence',
#   'Everybody saw their incompetence during the Afghanistan withdrawal'),
#  ('there is no doubt they tried to keep this secret so the public would not discover their incompetence',
#   'Incompetence no, treason yes.'),
#  ('Incompetence no, treason yes.',
#   'Oh this Administration is full of incompetence.'),
#  ('Oh this Administration is full of incompetence.',
#   'They\'ve displayed great competence in causing harm to our Country and "We the people...".'),
#  ('They\'ve displayed great competence in causing harm to our Country and "We the people...".',
#   '"Never attribute to malice that which can be explained by incompetence." Hanlon\'s Razor.'),
#  ('Incompetence no, treason yes.', "I'd argue both"),
#  ('there is no doubt they tried to keep this secret so the public would not discover their incompetence',
#   'Or treason.'),
#  ('there is no doubt they tried to keep this secret so the public would not discover their incompetence',
#   "Biden was informed Feb 1. The public the very next day. So Biden wasn't trying to keep it secret."),
#  ("Biden was informed Feb 1. The public the very next day. So Biden wasn't trying to keep it secret.",
#   'Keep drinking the kool aide . . . . .'),
#  ('there is no doubt they tried to keep this secret so the public would not discover their incompetence',
#   "It was a balloon!!! It's not as if it was one of a slew of Chinese spy satellites tracking our every move from outer space."),
#  ('there is no doubt they tried to keep this secret so the public would not discover their incompetence',
#   'You someone’s love for China.'),
#  ('there is no doubt they tried to keep this secret so the public would not discover their incompetence',
#   'We saw their incompetence on Day 1 when he stopped drilling for fossil fuels and opened the southern border!'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'In other words…it was a cover up.'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'this post violated our policy'),
#  ('this post violated our policy', 'It was visible to the naked eye.'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   "Nothing surprising about this. The DNC attempted to conceal Joe Bribem from the voters to get him installed. They've attempted to conceal the open border and their policy of flooding the US with millions more illegal aliens. They attempted to conceal the laptop before the election, and still attempt to conceal Joe Bribem's career of influence peddling. Everything about Joe Bribem and the Dem party is a fraud."),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'It was a poorly worded statement, but the intelligent capability, is clearly a reference to our own. Of course not taking out a hostile nations spy capability, is one of the worse decisions they could have made.They could have made up a story. We the public wouldn’t have known the difference'),
#  ('It was a poorly worded statement, but the intelligent capability, is clearly a reference to our own. Of course not taking out a hostile nations spy capability, is one of the worse decisions they could have made.They could have made up a story. We the public wouldn’t have known the difference',
#   "It was a balloon that was easily visible from the ground. There is nothing being given away detecting something that is seen with the Mark One eyeball. I'm not buying it was poorly worded."),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   '$$$$ to the big guy.'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'probably because by then, they collected all of our intelligence information'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'OUR intelligence capabilities. Way to comprehend.'),
#  ('OUR intelligence capabilities. Way to comprehend.',
#   'We evidently have few capabilities regarding detection of these surveillance balloons and there is some question as to our “ intelligence” as well.  Did they ever retrieve the 3 school U.S. sized Chinese spy system, or is elusive as to who brought the baggie of cocaine into the WH?'),
#  ('OUR intelligence capabilities. Way to comprehend.',
#   "So it's a secret that people look up, occasionally?"),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   "I took it to mean they didn't want to reveal OUR intelligence capabilities, although with these traitors, who knows."),
#  ("I took it to mean they didn't want to reveal OUR intelligence capabilities, although with these traitors, who knows.",
#   "It's a secret that people look up at the sky?"),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   "The fact that the Military was able to detect it in the first place reveals US capabilities the Chinese may not be aware of. Capiche? This isn't hard."),
#  ("The fact that the Military was able to detect it in the first place reveals US capabilities the Chinese may not be aware of. Capiche? This isn't hard.",
#   'It was visible from the ground with no equipment at all.'),
#  ('"A senior Biden administration official denied allegations that they attempt to conceal the incident, saying decisions were made to protect sensitive intelligence capabilities."Why protect China\'s intelligence capabilities?',
#   'Because someone is in the pocket of the Chinese. He was paid well for letting them get away with everything'),
#  ...]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.legacy.data import Field, BucketIterator, TabularDataset

import sqlite3
import spacy
from bs4 import BeautifulSoup

# Load English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load("en_core_web_sm")

# Define the fields for comments and replies
comment_field = Field(sequential=True, tokenize=lambda x: [tok.text for tok in nlp(x)], init_token='<sos>', eos_token='<eos>', lower=True)
reply_field = Field(sequential=True, tokenize=lambda x: [tok.text for tok in nlp(x)], init_token='<sos>', eos_token='<eos>', lower=True)

# Define the fields mapping to your database columns
fields = [('comment', comment_field), ('reply', reply_field)]

# Connect to the SQLite database and execute the query
conn = sqlite3.connect('news.db')
cursor = conn.cursor()
cursor.execute('SELECT c1.content, c2.content FROM comment as c1, comment as c2 WHERE c1.id = c2.parent_id')
data = cursor.fetchall()
conn.close()

# Clean up text by removing HTML elements
def clean_text(text):
    soup = BeautifulSoup(text, 'html.parser')
    cleaned_text = soup.get_text(separator=' ', strip=True)
    return cleaned_text

# Clean the data and create a TabularDataset
cleaned_data = [(clean_text(comment), clean_text(reply)) for comment, reply in data]
examples = [torchtext.legacy.data.Example.fromlist([comment, reply], fields) for comment, reply in cleaned_data]
dataset = torchtext.legacy.data.Dataset(examples, fields)

# Split the dataset into training and testing sets
train_data, test_data = dataset.split(split_ratio=0.8)

# Build the vocabulary
comment_field.build_vocab(train_data, min_freq=2)
reply_field.build_vocab(train_data, min_freq=2)

# Define the Seq2Seq model
class Seq2SeqModel(nn.Module):
    def __init__(self, input_dim, emb_dim, hidden_dim, output_dim):
        super(Seq2SeqModel, self).__init__()

        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.GRU(emb_dim, hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, src):
        embedded = self.embedding(src)
        output, hidden = self.rnn(embedded)
        return self.fc(hidden.squeeze(0))

# Set hyperparameters
input_dim = len(comment_field.vocab)
output_dim = len(reply_field.vocab)
emb_dim = 256
hidden_dim = 512
batch_size = 64

# Create model and optimizer
model = Seq2SeqModel(input_dim, emb_dim, hidden_dim, output_dim)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Create iterators
train_iterator, test_iterator = BucketIterator.splits(
    (train_data, test_data),
    batch_size=batch_size,
    sort_within_batch=True,
    sort_key=lambda x: len(x.comment),
    device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
)

# Train the model
num_epochs = 10
for epoch in range(num_epochs):
    for batch in train_iterator:
        optimizer.zero_grad()
        output = model(batch.comment)
        loss = criterion(output, batch.reply)
        loss.backward()
        optimizer.step()

# Save the trained model
torch.save(model.state_dict(), 'seq2seq_model.pth')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import torch.nn as nn
#       3 import torch.optim as optim
# ----> 4 from torchtext.legacy.data import Field, BucketIterator, TabularDataset
#       6 import sqlite3
#       7 import spacy
#
# ModuleNotFoundError: No module named 'torchtext.legacy'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.utils import download_from_url, extract_archive

import sqlite3
import spacy
from bs4 import BeautifulSoup

# Load English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load("en_core_web_sm")

# Connect to the SQLite database and execute the query
conn = sqlite3.connect('news.db')
cursor = conn.cursor()
cursor.execute('SELECT c1.content, c2.content FROM comment as c1, comment as c2 WHERE c1.id = c2.parent_id')
data = cursor.fetchall()
conn.close()

# Clean up text by removing HTML elements
def clean_text(text):
    soup = BeautifulSoup(text, 'html.parser')
    cleaned_text = soup.get_text(separator=' ', strip=True)
    return cleaned_text

# Clean the data
cleaned_data = [(clean_text(comment), clean_text(reply)) for comment, reply in data]

# Tokenize text using spaCy
def tokenize(text):
    return [tok.text for tok in nlp(text)]

# Preprocess data
processed_data = [(tokenize(comment), tokenize(reply)) for comment, reply in cleaned_data]

# Separate comments and replies
comments = [comment for comment, _ in processed_data]
replies = [reply for _, reply in processed_data]

# Create vocabulary
vocab = set()
for comment, reply in processed_data:
    vocab.update(comment)
    vocab.update(reply)

# Convert words to indices
word_to_idx = {word: idx for idx, word in enumerate(vocab)}

# Convert data to tensors
comments_tensor = torch.tensor([[word_to_idx[word] for word in comment] for comment, _ in processed_data])
replies_tensor = torch.tensor([[word_to_idx[word] for word in reply] for _, reply in processed_data])

# Define the Seq2Seq model
class Seq2SeqModel(nn.Module):
    def __init__(self, input_dim, emb_dim, hidden_dim, output_dim):
        super(Seq2SeqModel, self).__init__()

        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.GRU(emb_dim, hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, src):
        embedded = self.embedding(src)
        output, hidden = self.rnn(embedded)
        return self.fc(hidden.squeeze(0))

# Set hyperparameters
input_dim = len(vocab)
output_dim = len(vocab)
emb_dim = 256
hidden_dim = 512
batch_size = 64

# Create model and optimizer
model = Seq2SeqModel(input_dim, emb_dim, hidden_dim, output_dim)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Train the model (assuming you have labels/targets for the replies)
num_epochs = 10
for epoch in range(num_epochs):
    for comment, reply in zip(comments_tensor, replies_tensor):
        optimizer.zero_grad()
        output = model(comment.unsqueeze(0))
        loss = criterion(output, reply.unsqueeze(0))
        loss.backward()
        optimizer.step()

# Save the trained model
torch.save(model.state_dict(), 'seq2seq_model.pth')
# Out:
# /tmp/ipykernel_10174/4178662475.py:22: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, 'html.parser')
